# %%
import pandas as pd
import numpy as np

# %%
d = pd.Series(np.random.randint(1,10,9))

# %%
d
# Out:
# 0    6
# 1    6
# 2    4
# 3    1
# 4    6
# 5    7
# 6    6
# 7    1
# 8    7
# dtype: int64

# %%
d.sort_values()
# Out:
# 3    1
# 7    1
# 2    4
# 0    6
# 1    6
# 4    6
# 6    6
# 5    7
# 8    7
# dtype: int64

# %%
d.sort_index()
# Out:
# 0    6
# 1    6
# 2    4
# 3    1
# 4    6
# 5    7
# 6    6
# 7    1
# 8    7
# dtype: int64

# %%
d
# Out:
# 0    6
# 1    6
# 2    4
# 3    1
# 4    6
# 5    7
# 6    6
# 7    1
# 8    7
# dtype: int64

# %%
d.rank(method= 'first')
# Out:
# 0    4.0
# 1    5.0
# 2    3.0
# 3    1.0
# 4    6.0
# 5    8.0
# 6    7.0
# 7    2.0
# 8    9.0
# dtype: float64

# %%
d.rank(method = 'max')
# Out:
# 0    7.0
# 1    7.0
# 2    3.0
# 3    2.0
# 4    7.0
# 5    9.0
# 6    7.0
# 7    2.0
# 8    9.0
# dtype: float64

# %%
df = pd.DataFrame({'c':np.random.randint(1,100,50),'c2':np.random.randint(1,100,50),'c3':np.random.randint(1,100,50)})

# %%
df
# Out:
#      c  c2  c3
# 0   93  14  52
# 1   72  89  89
# 2   15  35  23
# 3   70  32  48
# 4   92  64  80
# 5   31  24  80
# 6   74  39  21
# 7   12  12  16
# 8   60  35  37
# 9   48  60  71
# 10  29   7  23
# 11  71  75   3
# 12  48  41  31
# 13  38  77  58
# 14  65   3   9
# 15  57   6  78
# 16  39  38  98
# 17  53  37  94
# 18  15  81  51
# 19  96  32  12
# 20   2  80  14
# 21  66  61  76
# 22  14  50  49
# 23  54  89  12
# 24  62  71  76
# 25  13  98  95
# 26  87  63  45
# 27  11  12   9
# 28  27  89  91
# 29  85  55  34
# 30  55  66  87
# 31  33  96   2
# 32   6  13  61
# 33  46  39  54
# 34  16  92  15
# 35  76  90  92
# 36  62  71  67
# 37  65   8  77
# 38  76  72  23
# 39  56  35  70
# 40  30  35  46
# 41  96  55  45
# 42  68  77  45
# 43  78  58  80
# 44  13   4  70
# 45   9  67   2
# 46  32  43  62
# 47  56  43  61
# 48  19  63  99
# 49  58  75  64

# %%
for i in range(1,11):
  df.iloc[np.random.randint(1,50),np.random.randint(3)] = np.nan

# %%
df
# Out:
#        c    c2    c3
# 0   93.0  14.0  52.0
# 1   72.0  89.0  89.0
# 2   15.0   NaN  23.0
# 3   70.0  32.0  48.0
# 4   92.0   NaN  80.0
# 5   31.0  24.0  80.0
# 6   74.0  39.0  21.0
# 7   12.0   NaN  16.0
# 8   60.0  35.0  37.0
# 9   48.0  60.0  71.0
# 10  29.0   7.0  23.0
# 11  71.0  75.0   3.0
# 12  48.0  41.0  31.0
# 13  38.0  77.0  58.0
# 14  65.0   3.0   9.0
# 15  57.0   6.0  78.0
# 16  39.0  38.0  98.0
# 17  53.0  37.0  94.0
# 18  15.0  81.0  51.0
# 19  96.0  32.0  12.0
# 20   2.0  80.0  14.0
# 21   NaN  61.0  76.0
# 22  14.0  50.0  49.0
# 23  54.0   NaN  12.0
# 24  62.0  71.0  76.0
# 25   NaN  98.0  95.0
# 26  87.0  63.0  45.0
# 27  11.0  12.0   9.0
# 28  27.0  89.0  91.0
# 29   NaN  55.0  34.0
# 30   NaN  66.0  87.0
# 31  33.0  96.0   2.0
# 32   6.0  13.0  61.0
# 33  46.0  39.0   NaN
# 34  16.0  92.0  15.0
# 35  76.0  90.0  92.0
# 36  62.0  71.0  67.0
# 37  65.0   8.0  77.0
# 38  76.0  72.0  23.0
# 39  56.0  35.0  70.0
# 40  30.0  35.0  46.0
# 41  96.0  55.0  45.0
# ...

# %%
df_col = df.columns[df.isna().sum()>=5]

# %%
df.drop(df_col,axis=1)
# Out:
#        c    c2    c3
# 0   93.0  14.0  52.0
# 1   72.0  89.0  89.0
# 2   15.0   NaN  23.0
# 3   70.0  32.0  48.0
# 4   92.0   NaN  80.0
# 5   31.0  24.0  80.0
# 6   74.0  39.0  21.0
# 7   12.0   NaN  16.0
# 8   60.0  35.0  37.0
# 9   48.0  60.0  71.0
# 10  29.0   7.0  23.0
# 11  71.0  75.0   3.0
# 12  48.0  41.0  31.0
# 13  38.0  77.0  58.0
# 14  65.0   3.0   9.0
# 15  57.0   6.0  78.0
# 16  39.0  38.0  98.0
# 17  53.0  37.0  94.0
# 18  15.0  81.0  51.0
# 19  96.0  32.0  12.0
# 20   2.0  80.0  14.0
# 21   NaN  61.0  76.0
# 22  14.0  50.0  49.0
# 23  54.0   NaN  12.0
# 24  62.0  71.0  76.0
# 25   NaN  98.0  95.0
# 26  87.0  63.0  45.0
# 27  11.0  12.0   9.0
# 28  27.0  89.0  91.0
# 29   NaN  55.0  34.0
# 30   NaN  66.0  87.0
# 31  33.0  96.0   2.0
# 32   6.0  13.0  61.0
# 33  46.0  39.0   NaN
# 34  16.0  92.0  15.0
# 35  76.0  90.0  92.0
# 36  62.0  71.0  67.0
# 37  65.0   8.0  77.0
# 38  76.0  72.0  23.0
# 39  56.0  35.0  70.0
# 40  30.0  35.0  46.0
# 41  96.0  55.0  45.0
# ...

# %%
d_ = pd.DataFrame({"c":[2,4,1,np.nan,33,np.nan,np.nan],"a":[5,6,2,9,7,6,0]})

# %%
d_
# Out:
#       c  a
# 0   2.0  5
# 1   4.0  6
# 2   1.0  2
# 3   NaN  9
# 4  33.0  7
# 5   NaN  6
# 6   NaN  0

# %%
d_c = d_.columns[d_.isna().sum()>2]

# %%
d_c
# Out:
# Index(['c'], dtype='object')

# %%
d_.drop(d_c,axis=1)
# Out:
#    a
# 0  5
# 1  6
# 2  2
# 3  9
# 4  7
# 5  6
# 6  0

# %%
d_.idxmax()
# Out:
# c    4
# a    3
# dtype: int64

# %%
d_s = d_.sum(axis = 1)

# %%
d_s
# Out:
# 0     7.0
# 1    10.0
# 2     3.0
# 3     9.0
# 4    40.0
# 5     6.0
# 6     0.0
# dtype: float64

# %%
d_s.idxmax()
# Out:
# 4

# %%
d_.drop(d_s.idxmax(),axis = 0)
# Out:
#      c  a
# 0  2.0  5
# 1  4.0  6
# 2  1.0  2
# 3  NaN  9
# 5  NaN  6
# 6  NaN  0
