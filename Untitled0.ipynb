# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(25).reshape((5,5)),index =["A","B","C","D","E"],columns = ['col1','col2','col3','col4','col5'])

# %%
print(df)
# Out:
#    col1  col2  col3  col4  col5
# A     0     1     2     3     4
# B     5     6     7     8     9
# C    10    11    12    13    14
# D    15    16    17    18    19
# E    20    21    22    23    24

# %%
df2 = df.reindex(index = ['A','B','D','E','F'])

# %%
print(df2)
# Out:
#    col1  col2  col3  col4  col5
# A     0     1     2     3     4
# B     5     6     7     8     9
# D    15    16    17    18    19
# E    20    21    22    23    24
# F    20    21    22    23    24

# %%
myar = np.array([[2,4,2],
                 [3,2,6],
                 [8,30,3]])

# %%
myar.argsort()
# Out:
# array([[0, 2, 1],
#        [1, 0, 2],
#        [2, 0, 1]])

# %%
np.__version__
# Out:
# '1.26.4'

# %%
# !pip install --upgrade numpy

# %%
# Out:
# '1.26.4'
